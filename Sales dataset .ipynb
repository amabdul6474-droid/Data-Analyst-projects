# %%
import pandas as pd

# %%
store = pd.read_csv(r'C:\Users\Abdulrahman\Downloads\archive (14)\Sample - Superstore.csv', encoding='latin1')

# %%
store.head(10)
# Out:
#    Row ID        Order ID Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812 2014-06-09   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812 2014-06-09   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812 2014-06-09   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812 2014-06-09   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812 2014-06-09   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
store['Sales'].sum()
# Out:
# np.float64(1099862.0727)

# %%
store['Profit'].sum()
# Out:
# np.float64(286397.0217)

# %%
store['Quantity'].sum()
# Out:
# np.int64(37873)

# %%
total_sales = store['Sales'].sum()
total_profit = store['Profit'].sum()

total_margin= store['Sales'].sum()/store['Profit'].sum()*100

# %%
print(total_margin)
# Out:
# 802.1036136005321

# %%
store.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
sales_of_year = store.groupby(store['Order Date'].dt.year)['Sales'].sum()
print(sales_of_year)
# Out:
# Order Date
# 2014    207995.9960
# 2015    221878.9240
# 2016    312726.8658
# 2017    357260.2869
# Name: Sales, dtype: float64

# %%
sales_of_month = store.groupby(store['Order Date'].dt.month)['Sales'].sum()

# %%
sales_of_month
# Out:
# Order Date
# 1      50914.3470
# 2      36411.1234
# 3      74808.3548
# 4      70582.7655
# 5      85740.7959
# 6      84544.7675
# 7      60097.8110
# 8      81247.6735
# 9     121114.4303
# 10     88338.9695
# 11    173362.9863
# 12    172698.0480
# Name: Sales, dtype: float64

# %%
store['Order Date'] = pd.to_datetime(store['Order Date'])

# %%
store['Month'] = store['Order Date'].dt.month_name()

# %%
store.groupby('Month')['Sales'].sum()# sales trend
# Out:
# Month
# April         70582.7655
# August        81247.6735
# December     172698.0480
# February      36411.1234
# January       50914.3470
# July          60097.8110
# June          84544.7675
# March         74808.3548
# May           85740.7959
# November     173362.9863
# October       88338.9695
# September    121114.4303
# Name: Sales, dtype: float64

# %%
top_product_sales = (store.groupby('Product Name')['Sales'].sum().sort_values(ascending= False).head(10))

# %%
top_product_sales
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          30099.914
# GBC Ibimaster 500 Manual ProClick Binding System                               16437.168
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      15749.910
# HON 5400 Series Task Chairs for Big and Tall                                   15631.854
# GBC DocuBind P400 Electric Binding System                                       9254.732
# Global Troy Executive Leather Low-Back Tilter                                   9117.836
# 3D Systems Cube Printer, 2nd Generation, Magenta                                9099.930
# Samsung Galaxy Mega 6.3                                                         9071.784
# Riverside Palais Royal Lawyers Bookcase, Royale Cherry Finish                   8985.996
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind     8642.732
# Name: Sales, dtype: float64

# %%
lowest_product_sales = (store.groupby('Product Name')['Sales'].sum().sort_values(ascending= False).tail(10))

# %%
lowest_product_sales
# Out:
# Product Name
# Sanford Colorific Eraseable Coloring Pencils, 12 Count                              3.280
# Storex Flexible Poly Binders with Double Pockets                                    3.168
# Hoover Replacement Belts For Soft Guard & Commercial Ltweight Upright Vacs, 2/Pk    3.160
# Acco Economy Flexible Poly Round Ring Binder                                        3.132
# GE General Purpose, Extra Long Life, Showcase & Floodlight Incandescent Bulbs       2.910
# Acco Recycled 2" Capacity Laser Printer Hanging Data Binders                        2.890
# Wilson Jones DublLock D-Ring Binders                                                2.025
# Insertable Tab Indexes For Data Binders                                             1.908
# Eureka Disposable Bags for Sanitaire Vibra Groomer I Upright Vac                    1.624
# Avery Binder Labels                                                                 1.167
# Name: Sales, dtype: float64

# %%
sales_of_caterorys = store.groupby('Category')['Sales'].sum().sort_values(ascending= False)

# %%
sales_of_caterorys
# Out:
# Category
# Technology         836154.0330
# Furniture          741999.7953
# Office Supplies    719047.0320
# Name: Sales, dtype: float64

# %%
sales_of_subcaterorys = (store.groupby('Sub-Category')['Sales'].sum().sort_values(ascending= False))

# %%
sales_of_subcaterorys
# Out:
# Sub-Category
# Phones         330007.0540
# Chairs         328449.1030
# Storage        223843.6080
# Tables         206965.5320
# Binders        203412.7330
# Machines       189238.6310
# Accessories    167380.3180
# Copiers        149528.0300
# Bookcases      114879.9963
# Appliances     107532.1610
# Furnishings     91705.1640
# Paper           78479.2060
# Supplies        46673.5380
# Art             27118.7920
# Envelopes       16476.4020
# Labels          12486.3120
# Fasteners        3024.2800
# Name: Sales, dtype: float64

# %%
top_10_customers= store.groupby('Customer Name')['Sales'].sum().sort_values(ascending= False).head(10)

# %%
top_10_customers
# Out:
# Customer Name
# Adrian Barton         12120.595
# Hunter Lopez          11713.828
# Tom Ashbrook          11649.210
# Sanjit Engle          10639.654
# Bill Shonely          10351.023
# Christopher Conant     8953.368
# Grant Thornton         8174.868
# Tom Boeckenhauer       7291.958
# Joseph Holt            6695.556
# Maria Etezadi          6220.506
# Name: Sales, dtype: float64

# %%
sales_of_segments = store.groupby('Segment')['Sales'].sum().sort_values(ascending= False).head(5)

# %%
sales_of_segments
# Out:
# Segment
# Consumer       1.161401e+06
# Corporate      7.061464e+05
# Home Office    4.296531e+05
# Name: Sales, dtype: float64

# %%
average_order_value= store.groupby('Order ID')['Sales'].sum().mean()
average_order_value
# Out:
# np.float64(219.577175623877)

# %%
sales_in_regions= store.groupby('Region')['Sales'].sum().sort_values(ascending= False)

# %%
sales_in_regions
# Out:
# Region
# West       332443.7055
# East       330694.6260
# Central    246314.5152
# South      190409.2260
# Name: Sales, dtype: float64

# %%
loss_region = store.groupby('Region')['Profit'].sum().sort_values().tail(1)
loss_region
# Out:
# Region
# East    52445.6307
# Name: Profit, dtype: float64

# %%
sales_in_state= store.groupby('State')['Sales'].sum().sort_values(ascending= False)
sales_in_state
# Out:
# State
# California              213274.6305
# New York                148208.7590
# Texas                    78250.1842
# Washington               57309.1160
# Pennsylvania             55286.6520
# Illinois                 48690.7650
# Michigan                 45541.3760
# Florida                  41308.4900
# Ohio                     40006.4760
# Virginia                 38420.1500
# North Carolina           34980.7220
# New Jersey               23433.5060
# Delaware                 19475.3660
# Indiana                  17759.7100
# Wisconsin                17083.8300
# Kentucky                 16882.0300
# Arizona                  16393.2140
# Georgia                  14020.9100
# Tennessee                13837.2240
# Minnesota                12590.7000
# Oklahoma                 12224.7600
# Colorado                 12211.4370
# Massachusetts            11743.2200
# Rhode Island              8647.6940
# Nevada                    8177.2120
# Alabama                   7802.1500
# ...

# %%
most_profitable_category= store.groupby('Category')['Profit'].sum().sort_values(ascending=False).head(1)
most_profitable_category
# Out:
# Category
# Technology    70157.5741
# Name: Profit, dtype: float64

# %%
least_profitable_category= store.groupby('Category')['Profit'].sum().sort_values(ascending=False).tail(1)
least_profitable_category
# Out:
# Category
# Furniture    7569.1733
# Name: Profit, dtype: float64

# %%
loss_products= store.groupby('Product Name')['Profit'].sum().sort_values(ascending=False)
loss_products.tail(1)
# Out:
# Product Name
# Cubify CubeX 3D Printer Triple Head Print   -3839.9904
# Name: Profit, dtype: float64

# %%
product_discounts= store.groupby('Product Name')['Discount'].sum().sort_values(ascending=False)
product_discounts
# Out:
# Product Name
# GBC Instant Report Kit                              5.4
# Avery Non-Stick Binders                             4.6
# Vinyl Sectional Post Binders                        4.0
# GBC Ibimaster 500 Manual ProClick Binding System    3.8
# GBC Standard Therm-A-Bind Covers                    3.8
#                                                    ...
# DAX Cubicle Frames, 8-1/2 x 11                      0.0
# Stockwell Push Pins                                 0.0
# DAX Natural Wood-Tone Poster Frame                  0.0
# Stiletto Hand Letter Openers                        0.0
# Disposable Triple-Filter Dust Bags                  0.0
# Name: Discount, Length: 1720, dtype: float64
